# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
df = pd.read_csv("..\\data\\raw\\binance_data.csv")

# %%
print(df.head())

df['close'].plot(figsize=(12,6), title='Prezzo BTC/EUR')
plt.show()
# Out:
#              open_time       open       high        low      close    volume
# 0  2025-07-14 22:00:00  102805.13  102948.49  102644.51  102723.53  39.60099
# 1  2025-07-14 23:00:00  102723.53  102726.98  102555.28  102646.17  37.49855
# 2  2025-07-15 00:00:00  102646.17  102651.30  102118.62  102285.79  51.74118
# 3  2025-07-15 01:00:00  102285.79  102320.37  101560.13  101560.13  68.50542
# 4  2025-07-15 02:00:00  101569.13  101743.58  100919.20  101245.54  63.76644
